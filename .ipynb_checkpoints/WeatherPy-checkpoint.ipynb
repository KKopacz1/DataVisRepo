# %% [markdown]
# WeatherPy Homework

# %%
#Insert Dependencies
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests as req

from citipy import citipy
import openweathermapy as owm
import datetime
now = datetime.datetime.now()

# %%
#Define API Key and Settings
api_key = "f42f699340a84b135d17535895cdd260"
setting = {"units": "imperial", "appid": api_key}

# %% [markdown]
# Generate Random Cities

# %%
#Create Latitue and Longitute Range
lat = list(np.arange(-90, 90.01, 0.01))
long = list(np.arange(-180, 180.01, 0.01))
lat_samples = random.sample(lat,2500)
long_samples = random.sample(long, 2500)

#Create a dataframe from the random Lat&Long values
cities_df = pd.DataFrame({"Latitude":lat_samples, "Longitude":long_samples})
cities_df["City"] = ""
cities_df["Country"] = ""

#Find country for each Lat&Long
for index,row in cities_df.iterrows():
    city = citipy.nearest_city(row["Latitude"], row["Longitude"])
    cities_df.set_value(index, "City", city.city_name)
    cities_df.set_value(index, "Country", city.country_code)
cities_df = cities_df.drop(cities_df.columns[[0,1]], axis=1)
cities_df = cities_df.drop_duplicates(['City'], keep="first")

#Random Sample of Cities
cities_df = cities_df.sample(n=600)
cities_df = cities_df.reset_index(drop=True)

cities_df.head()
# Out:
#       City Country
# 0  labuhan      id
# 1  nguruka      tz
# 2  lithgow      au
# 3  qaanaaq      gl
# 4   riyadh      sa

# %%
# Get data for each city in cities_DF
weather_data = []

url="https://api.openweathermap.org/data/2.5/weather?appid=" + api_key + "&units=imperial&q="

for index,row in cities_df.iterrows():  
    print("\nFinding City %s|%s,%s"%((index+1),row["City"],row["Country"]))
    print("\n"+url+"%s,%s"%(row["City"].replace(" ","+"),row["Country"]))
    try:
        response = owm.get_current("%s,%s"%(row["City"],row["Country"]), **settings)
        # Appending the response to the weather_Data
        weather_data.append(response)
    except:
        print("")
# Out:
# Finding City 1|labuhan,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=labuhan,id
#
#
# Finding City 2|nguruka,tz
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=nguruka,tz
#
#
# Finding City 3|lithgow,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=lithgow,au
#
#
# Finding City 4|qaanaaq,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=qaanaaq,gl
#
#
# Finding City 5|riyadh,sa
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=riyadh,sa
#
#
# Finding City 6|vostok,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=vostok,ru
#
#
# Finding City 7|kieta,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kieta,pg
#
#
# Finding City 8|thongwa,mm
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=thongwa,mm
#
#
# Finding City 9|mnogovershinnyy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mnogovershinnyy,ru
#
#
# Finding City 10|ferzikovo,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ferzikovo,ru
#
#
# Finding City 11|grindavik,is
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=grindavik,is
#
#
# Finding City 12|hami,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=hami,cn
#
#
# Finding City 13|caraballeda,ve
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=caraballeda,ve
#
#
# Finding City 14|san andres,co
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=san+andres,co
#
#
# Finding City 15|paradwip,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=paradwip,in
#
#
# Finding City 16|sitka,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sitka,us
#
#
# Finding City 17|new norfolk,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=new+norfolk,au
#
#
# Finding City 18|charters towers,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=charters+towers,au
#
#
# Finding City 19|royan,fr
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=royan,fr
#
#
# Finding City 20|chino valley,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=chino+valley,us
#
#
# Finding City 21|vestmannaeyjar,is
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=vestmannaeyjar,is
#
#
# Finding City 22|sadovoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sadovoye,ru
#
#
# Finding City 23|ishikari,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ishikari,jp
#
#
# Finding City 24|vao,nc
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=vao,nc
#
#
# Finding City 25|chimbote,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=chimbote,pe
#
#
# Finding City 26|borovskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=borovskiy,ru
#
#
# Finding City 27|vardo,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=vardo,no
#
#
# Finding City 28|north bend,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=north+bend,us
#
#
# Finding City 29|yinchuan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=yinchuan,cn
#
#
# Finding City 30|barrow,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=barrow,us
#
#
# Finding City 31|derzhavinsk,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=derzhavinsk,kz
#
#
# Finding City 32|braganca,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=braganca,br
#
#
# Finding City 33|bulgan,mn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bulgan,mn
#
#
# Finding City 34|oktyabrskoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=oktyabrskoye,ru
#
#
# Finding City 35|kariba,zw
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kariba,zw
#
#
# Finding City 36|jablanica,ba
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=jablanica,ba
#
#
# Finding City 37|rio grande,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=rio+grande,br
#
#
# Finding City 38|vegreville,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=vegreville,ca
#
#
# Finding City 39|roma,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=roma,au
#
#
# Finding City 40|ilulissat,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ilulissat,gl
#
#
# Finding City 41|toowoomba,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=toowoomba,au
#
#
# Finding City 42|acapulco,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=acapulco,mx
#
#
# Finding City 43|jabinyanah,tn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=jabinyanah,tn
#
#
# Finding City 44|san cristobal,ec
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=san+cristobal,ec
#
#
# Finding City 45|auki,sb
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=auki,sb
#
#
# Finding City 46|raudeberg,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=raudeberg,no
#
#
# Finding City 47|huarmey,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=huarmey,pe
#
#
# Finding City 48|baracoa,cu
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=baracoa,cu
#
#
# Finding City 49|sola,vu
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sola,vu
#
#
# Finding City 50|lebu,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=lebu,cl
#
#
# Finding City 51|carauari,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=carauari,br
#
#
# Finding City 52|ponta do sol,cv
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ponta+do+sol,cv
#
#
# Finding City 53|aluksne,lv
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=aluksne,lv
#
#
# Finding City 54|ambon,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ambon,id
#
#
# Finding City 55|pasni,pk
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=pasni,pk
#
#
# Finding City 56|chauk,mm
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=chauk,mm
#
#
# Finding City 57|mumford,gh
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mumford,gh
#
#
# Finding City 58|elliot lake,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=elliot+lake,ca
#
#
# Finding City 59|okhotsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=okhotsk,ru
#
#
# Finding City 60|padang,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=padang,id
#
#
# Finding City 61|mayo,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mayo,ca
#
#
# Finding City 62|bardiyah,ly
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bardiyah,ly
#
#
# Finding City 63|calabozo,ve
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=calabozo,ve
#
#
# Finding City 64|ankazoabo,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ankazoabo,mg
#
#
# Finding City 65|sao geraldo do araguaia,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sao+geraldo+do+araguaia,br
#
#
# Finding City 66|sisimiut,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sisimiut,gl
#
#
# Finding City 67|hongjiang,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=hongjiang,cn
#
#
# Finding City 68|torbay,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=torbay,ca
#
#
# Finding City 69|preobrazheniye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=preobrazheniye,ru
#
#
# Finding City 70|pampierstad,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=pampierstad,za
#
#
# Finding City 71|swellendam,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=swellendam,za
#
#
# Finding City 72|fort nelson,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=fort+nelson,ca
#
#
# Finding City 73|moranbah,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=moranbah,au
#
#
# Finding City 74|skjervoy,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=skjervoy,no
#
#
# Finding City 75|itarema,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=itarema,br
#
#
# Finding City 76|tongliao,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tongliao,cn
#
#
# Finding City 77|san juan,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=san+juan,ar
#
#
# Finding City 78|netarhat,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=netarhat,in
#
#
# Finding City 79|napasar,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=napasar,in
#
#
# Finding City 80|cumberland,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=cumberland,us
#
#
# Finding City 81|huangchuan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=huangchuan,cn
#
#
# Finding City 82|elko,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=elko,us
#
#
# Finding City 83|sambava,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sambava,mg
#
#
# Finding City 84|boende,cd
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=boende,cd
#
#
# Finding City 85|albany,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=albany,au
#
#
# Finding City 86|saint-philippe,re
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=saint-philippe,re
#
#
# Finding City 87|domoszlo,hu
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=domoszlo,hu
#
#
# Finding City 88|lamar,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=lamar,us
#
#
# Finding City 89|attawapiskat,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=attawapiskat,ca
#
#
# Finding City 90|matamoros,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=matamoros,mx
#
#
# Finding City 91|toliary,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=toliary,mg
#
#
# Finding City 92|seminole,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=seminole,us
#
#
# Finding City 93|te anau,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=te+anau,nz
#
#
# Finding City 94|pokosnoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=pokosnoye,ru
#
#
# Finding City 95|leningradskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=leningradskiy,ru
#
#
# Finding City 96|myaundzha,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=myaundzha,ru
#
#
# Finding City 97|jackson,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=jackson,us
#
#
# Finding City 98|carnarvon,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=carnarvon,au
#
#
# Finding City 99|burnie,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=burnie,au
#
#
# Finding City 100|jhelum,pk
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=jhelum,pk
#
#
# Finding City 101|rikitea,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=rikitea,pf
#
#
# Finding City 102|kushiro,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kushiro,jp
#
#
# Finding City 103|janakpur,np
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=janakpur,np
#
#
# Finding City 104|faya,td
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=faya,td
#
#
# Finding City 105|muyezerskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=muyezerskiy,ru
#
#
# Finding City 106|hostotipaquillo,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=hostotipaquillo,mx
#
#
# Finding City 107|tiznit,ma
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tiznit,ma
#
#
# Finding City 108|flinders,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=flinders,au
#
#
# Finding City 109|rio grande city,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=rio+grande+city,us
#
#
# Finding City 110|khorinsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=khorinsk,ru
#
#
# Finding City 111|geraldton,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=geraldton,au
#
#
# Finding City 112|sliven,bg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sliven,bg
#
#
# Finding City 113|jambi,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=jambi,id
#
#
# Finding City 114|avarua,ck
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=avarua,ck
#
#
# Finding City 115|benghazi,ly
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=benghazi,ly
#
#
# Finding City 116|voh,nc
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=voh,nc
#
#
# Finding City 117|mullaitivu,lk
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mullaitivu,lk
#
#
# Finding City 118|ardakan,ir
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ardakan,ir
#
#
# Finding City 119|kytmanovo,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kytmanovo,ru
#
#
# Finding City 120|san carlos de bariloche,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=san+carlos+de+bariloche,ar
#
#
# Finding City 121|bacuit,ph
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bacuit,ph
#
#
# Finding City 122|grand river south east,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=grand+river+south+east,mu
#
#
# Finding City 123|northam,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=northam,au
#
#
# Finding City 124|impfondo,cg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=impfondo,cg
#
#
# Finding City 125|yunjinghong,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=yunjinghong,cn
#
#
# Finding City 126|belushya guba,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=belushya+guba,ru
#
#
# Finding City 127|gizo,sb
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=gizo,sb
#
#
# Finding City 128|ito,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ito,jp
#
#
# Finding City 129|kerugoya,ke
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kerugoya,ke
#
#
# Finding City 130|tocopilla,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tocopilla,cl
#
#
# Finding City 131|pula,hr
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=pula,hr
#
#
# Finding City 132|kisangani,cd
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kisangani,cd
#
#
# Finding City 133|khatanga,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=khatanga,ru
#
#
# Finding City 134|bahia de caraquez,ec
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bahia+de+caraquez,ec
#
#
# Finding City 135|gorele,tr
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=gorele,tr
#
#
# Finding City 136|plattsburgh,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=plattsburgh,us
#
#
# Finding City 137|petropavlovsk-kamchatskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=petropavlovsk-kamchatskiy,ru
#
#
# Finding City 138|qaqortoq,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=qaqortoq,gl
#
#
# Finding City 139|malakal,sd
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=malakal,sd
#
#
# Finding City 140|saldanha,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=saldanha,za
#
#
# Finding City 141|vila do maio,cv
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=vila+do+maio,cv
#
#
# Finding City 142|ekuvukeni,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ekuvukeni,za
#
#
# Finding City 143|cartagena del chaira,co
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=cartagena+del+chaira,co
#
#
# Finding City 144|hailin,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=hailin,cn
#
#
# Finding City 145|valdivia,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=valdivia,cl
#
#
# Finding City 146|arica,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=arica,cl
#
#
# Finding City 147|phan rang,vn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=phan+rang,vn
#
#
# Finding City 148|garden city,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=garden+city,us
#
#
# Finding City 149|barentsburg,sj
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=barentsburg,sj
#
#
# Finding City 150|itacurubi del rosario,py
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=itacurubi+del+rosario,py
#
#
# Finding City 151|manaus,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=manaus,br
#
#
# Finding City 152|mahroni,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mahroni,in
#
#
# Finding City 153|kenai,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kenai,us
#
#
# Finding City 154|tiarei,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tiarei,pf
#
#
# Finding City 155|hirson,fr
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=hirson,fr
#
#
# Finding City 156|iqaluit,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=iqaluit,ca
#
#
# Finding City 157|huilong,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=huilong,cn
#
#
# Finding City 158|tiksi,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tiksi,ru
#
#
# Finding City 159|houston,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=houston,ca
#
#
# Finding City 160|tselinnoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tselinnoye,ru
#
#
# Finding City 161|lalomanu,ws
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=lalomanu,ws
#
#
# Finding City 162|tahoua,ne
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tahoua,ne
#
#
# Finding City 163|khonuu,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=khonuu,ru
#
#
# Finding City 164|maxingal,ph
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=maxingal,ph
#
#
# Finding City 165|fremont,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=fremont,us
#
#
# Finding City 166|suez,eg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=suez,eg
#
#
# Finding City 167|sistranda,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sistranda,no
#
#
# Finding City 168|hay river,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=hay+river,ca
#
#
# Finding City 169|talnakh,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=talnakh,ru
#
#
# Finding City 170|betul,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=betul,in
#
#
# Finding City 171|klyuchi,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=klyuchi,ru
#
#
# Finding City 172|bahir dar,et
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bahir+dar,et
#
#
# Finding City 173|lac du bonnet,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=lac+du+bonnet,ca
#
#
# Finding City 174|sentyabrskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sentyabrskiy,ru
#
#
# Finding City 175|tucuman,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tucuman,ar
#
#
# Finding City 176|lieksa,fi
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=lieksa,fi
#
#
# Finding City 177|russell,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=russell,nz
#
#
# Finding City 178|mandalgovi,mn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mandalgovi,mn
#
#
# Finding City 179|airai,pw
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=airai,pw
#
#
# Finding City 180|inuvik,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=inuvik,ca
#
#
# Finding City 181|victoria,sc
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=victoria,sc
#
#
# Finding City 182|bredasdorp,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bredasdorp,za
#
#
# Finding City 183|burscheid,de
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=burscheid,de
#
#
# Finding City 184|rancho palos verdes,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=rancho+palos+verdes,us
#
#
# Finding City 185|singaparna,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=singaparna,id
#
#
# Finding City 186|ahuimanu,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ahuimanu,us
#
#
# Finding City 187|zatoka,ua
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=zatoka,ua
#
#
# Finding City 188|kiunga,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kiunga,pg
#
#
# Finding City 189|revda,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=revda,ru
#
#
# Finding City 190|kokopo,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kokopo,pg
#
#
# Finding City 191|pacific grove,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=pacific+grove,us
#
#
# Finding City 192|port hardy,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=port+hardy,ca
#
#
# Finding City 193|vrangel,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=vrangel,ru
#
#
# Finding City 194|sur,om
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sur,om
#
#
# Finding City 195|bay city,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bay+city,us
#
#
# Finding City 196|weinan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=weinan,cn
#
#
# Finding City 197|kirillov,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kirillov,ru
#
#
# Finding City 198|unguia,co
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=unguia,co
#
#
# Finding City 199|mastic beach,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mastic+beach,us
#
#
# Finding City 200|atar,mr
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=atar,mr
#
#
# Finding City 201|nardaran,az
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=nardaran,az
#
#
# Finding City 202|el alto,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=el+alto,pe
#
#
# Finding City 203|coquimbo,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=coquimbo,cl
#
#
# Finding City 204|tooele,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tooele,us
#
#
# Finding City 205|lucea,jm
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=lucea,jm
#
#
# Finding City 206|sao filipe,cv
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sao+filipe,cv
#
#
# Finding City 207|eenhana,na
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=eenhana,na
#
#
# Finding City 208|karratha,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=karratha,au
#
#
# Finding City 209|iwanai,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=iwanai,jp
#
#
# Finding City 210|upernavik,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=upernavik,gl
#
#
# Finding City 211|san quintin,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=san+quintin,mx
#
#
# Finding City 212|nikolskoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=nikolskoye,ru
#
#
# Finding City 213|yeppoon,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=yeppoon,au
#
#
# Finding City 214|faanui,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=faanui,pf
#
#
# Finding City 215|yafran,ly
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=yafran,ly
#
#
# Finding City 216|vila velha,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=vila+velha,br
#
#
# Finding City 217|zitacuaro,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=zitacuaro,mx
#
#
# Finding City 218|bilibino,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bilibino,ru
#
#
# Finding City 219|ulagan,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ulagan,ru
#
#
# Finding City 220|nata,bw
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=nata,bw
#
#
# Finding City 221|barra patuca,hn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=barra+patuca,hn
#
#
# Finding City 222|karauzyak,uz
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=karauzyak,uz
#
#
# Finding City 223|pisco,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=pisco,pe
#
#
# Finding City 224|tabuk,sa
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tabuk,sa
#
#
# Finding City 225|shubarkuduk,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=shubarkuduk,kz
#
#
# Finding City 226|wukari,ng
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=wukari,ng
#
#
# Finding City 227|jiutai,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=jiutai,cn
#
#
# Finding City 228|ondorhaan,mn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ondorhaan,mn
#
#
# Finding City 229|touros,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=touros,br
#
#
# Finding City 230|tome,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tome,cl
#
#
# Finding City 231|merauke,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=merauke,id
#
#
# Finding City 232|nouadhibou,mr
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=nouadhibou,mr
#
#
# Finding City 233|mount gambier,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mount+gambier,au
#
#
# Finding City 234|constitucion,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=constitucion,mx
#
#
# Finding City 235|comodoro rivadavia,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=comodoro+rivadavia,ar
#
#
# Finding City 236|semporna,my
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=semporna,my
#
#
# Finding City 237|bathsheba,bb
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bathsheba,bb
#
#
# Finding City 238|vyartsilya,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=vyartsilya,ru
#
#
# Finding City 239|vitim,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=vitim,ru
#
#
# Finding City 240|the valley,ai
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=the+valley,ai
#
#
# Finding City 241|brownfield,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=brownfield,us
#
#
# Finding City 242|thunder bay,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=thunder+bay,ca
#
#
# Finding City 243|katherine,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=katherine,au
#
#
# Finding City 244|gwanda,zw
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=gwanda,zw
#
#
# Finding City 245|nelson bay,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=nelson+bay,au
#
#
# Finding City 246|marawi,sd
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=marawi,sd
#
#
# Finding City 247|mayumba,ga
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mayumba,ga
#
#
# Finding City 248|hambantota,lk
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=hambantota,lk
#
#
# Finding City 249|ancud,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ancud,cl
#
#
# Finding City 250|bethel,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bethel,us
#
#
# Finding City 251|falkoping,se
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=falkoping,se
#
#
# Finding City 252|oum hadjer,td
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=oum+hadjer,td
#
#
# Finding City 253|sao joao da barra,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sao+joao+da+barra,br
#
#
# Finding City 254|lolua,tv
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=lolua,tv
#
#
# Finding City 255|srandakan,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=srandakan,id
#
#
# Finding City 256|tanete,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tanete,id
#
#
# Finding City 257|kozan,tr
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kozan,tr
#
#
# Finding City 258|mmabatho,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mmabatho,za
#
#
# Finding City 259|lodja,cd
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=lodja,cd
#
#
# Finding City 260|lompoc,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=lompoc,us
#
#
# Finding City 261|madang,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=madang,pg
#
#
# Finding City 262|yaan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=yaan,cn
#
#
# Finding City 263|le port,re
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=le+port,re
#
#
# Finding City 264|morant bay,jm
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=morant+bay,jm
#
#
# Finding City 265|letlhakeng,bw
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=letlhakeng,bw
#
#
# Finding City 266|hasaki,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=hasaki,jp
#
#
# Finding City 267|jaguey grande,cu
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=jaguey+grande,cu
#
#
# Finding City 268|hermanus,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=hermanus,za
#
#
# Finding City 269|boston,ph
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=boston,ph
#
#
# Finding City 270|damara,cf
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=damara,cf
#
#
# Finding City 271|daru,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=daru,pg
#
#
# Finding City 272|provideniya,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=provideniya,ru
#
#
# Finding City 273|praia,cv
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=praia,cv
#
#
# Finding City 274|mao,td
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mao,td
#
#
# Finding City 275|cherskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=cherskiy,ru
#
#
# Finding City 276|nishihara,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=nishihara,jp
#
#
# Finding City 277|alofi,nu
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=alofi,nu
#
#
# Finding City 278|magadan,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=magadan,ru
#
#
# Finding City 279|birchis,ro
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=birchis,ro
#
#
# Finding City 280|pemberton,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=pemberton,ca
#
#
# Finding City 281|namibe,ao
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=namibe,ao
#
#
# Finding City 282|formoso do araguaia,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=formoso+do+araguaia,br
#
#
# Finding City 283|hofn,is
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=hofn,is
#
#
# Finding City 284|yulara,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=yulara,au
#
#
# Finding City 285|moose factory,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=moose+factory,ca
#
#
# Finding City 286|madurai,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=madurai,in
#
#
# Finding City 287|artvin,tr
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=artvin,tr
#
#
# Finding City 288|dubrovka,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=dubrovka,ru
#
#
# Finding City 289|novikovo,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=novikovo,ru
# Finding City 290|lar gerd,af
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=lar+gerd,af
#
#
# Finding City 291|sinnamary,gf
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sinnamary,gf
#
#
# Finding City 292|illoqqortoormiut,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=illoqqortoormiut,gl
#
#
# Finding City 293|awjilah,ly
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=awjilah,ly
#
#
# Finding City 294|trinidad,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=trinidad,us
#
#
# Finding City 295|jurm,af
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=jurm,af
#
#
# Finding City 296|finschhafen,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=finschhafen,pg
#
#
# Finding City 297|tikhvin,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tikhvin,ru
#
#
# Finding City 298|mattru,sl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mattru,sl
#
#
# Finding City 299|maniwaki,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=maniwaki,ca
#
#
# Finding City 300|sumbawa,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sumbawa,id
#
#
# Finding City 301|canyon,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=canyon,us
#
#
# Finding City 302|utiroa,ki
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=utiroa,ki
#
#
# Finding City 303|eureka,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=eureka,us
#
#
# Finding City 304|morros,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=morros,br
#
#
# Finding City 305|butaritari,ki
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=butaritari,ki
#
#
# Finding City 306|mahebourg,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mahebourg,mu
#
#
# Finding City 307|mahajanga,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mahajanga,mg
#
#
# Finding City 308|camacha,pt
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=camacha,pt
#
#
# Finding City 309|hegang,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=hegang,cn
#
#
# Finding City 310|mangrol,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mangrol,in
#
#
# Finding City 311|dingle,ie
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=dingle,ie
#
#
# Finding City 312|aguimes,es
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=aguimes,es
#
#
# Finding City 313|chicama,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=chicama,pe
#
#
# Finding City 314|dhidhdhoo,mv
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=dhidhdhoo,mv
#
#
# Finding City 315|karakol,kg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=karakol,kg
#
#
# Finding City 316|dongkan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=dongkan,cn
#
#
# Finding City 317|dolores,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=dolores,ar
#
#
# Finding City 318|jieshi,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=jieshi,cn
#
#
# Finding City 319|fagernes,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=fagernes,no
#
#
# Finding City 320|mwandiga,tz
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mwandiga,tz
#
#
# Finding City 321|bara,sd
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bara,sd
#
#
# Finding City 322|vung tau,vn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=vung+tau,vn
#
#
# Finding City 323|visconde do rio branco,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=visconde+do+rio+branco,br
#
#
# Finding City 324|noumea,nc
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=noumea,nc
#
#
# ...
#
#
# Finding City 493|bluff,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bluff,nz
#
#
# Finding City 494|la ronge,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=la+ronge,ca
#
#
# Finding City 495|tezu,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tezu,in
#
#
# Finding City 496|celestun,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=celestun,mx
#
#
# Finding City 497|upata,ve
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=upata,ve
#
#
# Finding City 498|morlaix,fr
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=morlaix,fr
#
#
# Finding City 499|bolgatanga,gh
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bolgatanga,gh
#
#
# Finding City 500|parrita,cr
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=parrita,cr
#
#
# Finding City 501|nemuro,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=nemuro,jp
#
#
# Finding City 502|palu,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=palu,id
#
#
# Finding City 503|genhe,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=genhe,cn
#
#
# Finding City 504|altay,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=altay,cn
#
#
# Finding City 505|pecos,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=pecos,us
#
#
# Finding City 506|cukai,my
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=cukai,my
#
#
# Finding City 507|katsuura,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=katsuura,jp
#
#
# Finding City 508|buin,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=buin,pg
#
#
# Finding City 509|georgetown,sh
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=georgetown,sh
#
#
# Finding City 510|muisne,ec
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=muisne,ec
#
#
# Finding City 511|bolungarvik,is
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bolungarvik,is
#
#
# Finding City 512|maragogi,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=maragogi,br
#
#
# Finding City 513|mackay,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mackay,au
#
#
# Finding City 514|orje,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=orje,no
#
#
# Finding City 515|cidreira,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=cidreira,br
#
#
# Finding City 516|strathpeffer,gb
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=strathpeffer,gb
#
#
# Finding City 517|kaitangata,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kaitangata,nz
#
#
# Finding City 518|bodden town,ky
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bodden+town,ky
#
#
# Finding City 519|gamba,ga
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=gamba,ga
#
#
# Finding City 520|taoudenni,ml
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=taoudenni,ml
#
#
# Finding City 521|borsa,ro
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=borsa,ro
#
#
# Finding City 522|aykhal,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=aykhal,ru
#
#
# Finding City 523|issaquah,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=issaquah,us
#
#
# Finding City 524|weligama,lk
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=weligama,lk
#
#
# Finding City 525|razole,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=razole,in
#
#
# Finding City 526|zemio,cf
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=zemio,cf
#
#
# Finding City 527|tevaitoa,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tevaitoa,pf
#
#
# Finding City 528|padilla,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=padilla,mx
#
#
# Finding City 529|sobolevo,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sobolevo,ru
#
#
# Finding City 530|muroto,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=muroto,jp
#
#
# Finding City 531|salalah,om
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=salalah,om
#
#
# Finding City 532|kenora,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kenora,ca
#
#
# Finding City 533|mudgee,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mudgee,au
#
#
# Finding City 534|neyshabur,ir
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=neyshabur,ir
#
#
# Finding City 535|buraydah,sa
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=buraydah,sa
#
#
# Finding City 536|sibu,my
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sibu,my
#
#
# Finding City 537|fairbanks,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=fairbanks,us
#
#
# Finding City 538|axim,gh
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=axim,gh
#
#
# Finding City 539|shache,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=shache,cn
#
#
# Finding City 540|yar-sale,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=yar-sale,ru
#
#
# Finding City 541|half moon bay,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=half+moon+bay,us
#
#
# Finding City 542|meadow lake,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=meadow+lake,ca
#
#
# Finding City 543|teknaf,bd
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=teknaf,bd
#
#
# Finding City 544|longyearbyen,sj
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=longyearbyen,sj
#
#
# Finding City 545|makakilo city,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=makakilo+city,us
#
#
# Finding City 546|ano mera,gr
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ano+mera,gr
#
#
# Finding City 547|kupino,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kupino,ru
#
#
# Finding City 548|lagoa,pt
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=lagoa,pt
#
#
# Finding City 549|puerto madryn,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=puerto+madryn,ar
#
#
# Finding City 550|tuktoyaktuk,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tuktoyaktuk,ca
#
#
# Finding City 551|harper,lr
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=harper,lr
#
#
# Finding City 552|turukhansk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=turukhansk,ru
#
#
# Finding City 553|saint cloud,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=saint+cloud,us
#
#
# Finding City 554|port antonio,jm
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=port+antonio,jm
#
#
# Finding City 555|prince rupert,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=prince+rupert,ca
#
#
# Finding City 556|kapit,my
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kapit,my
#
#
# Finding City 557|saint-leu,re
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=saint-leu,re
#
#
# Finding City 558|souillac,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=souillac,mu
#
#
# Finding City 559|karaul,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=karaul,ru
#
#
# Finding City 560|dhanera,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=dhanera,in
#
#
# Finding City 561|syracuse,it
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=syracuse,it
#
#
# Finding City 562|ambilobe,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=ambilobe,mg
#
#
# Finding City 563|point pedro,lk
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=point+pedro,lk
#
#
# Finding City 564|asau,tv
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=asau,tv
#
#
# Finding City 565|leshukonskoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=leshukonskoye,ru
#
#
# Finding City 566|meyungs,pw
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=meyungs,pw
#
#
# Finding City 567|husavik,is
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=husavik,is
#
#
# Finding City 568|asuncion,py
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=asuncion,py
#
#
# Finding City 569|mecca,sa
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mecca,sa
#
#
# Finding City 570|sydney,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sydney,au
#
#
# Finding City 571|bulaevo,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bulaevo,kz
#
#
# Finding City 572|saint anthony,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=saint+anthony,ca
#
#
# Finding City 573|galesong,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=galesong,id
#
#
# Finding City 574|kuopio,fi
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kuopio,fi
#
#
# Finding City 575|bandarbeyla,so
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bandarbeyla,so
#
#
# Finding City 576|bosaso,so
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=bosaso,so
#
#
# Finding City 577|tabou,ci
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tabou,ci
#
#
# Finding City 578|inongo,cd
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=inongo,cd
#
#
# Finding City 579|biak,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=biak,id
#
#
# Finding City 580|tougan,bf
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=tougan,bf
#
#
# Finding City 581|lavrentiya,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=lavrentiya,ru
#
#
# Finding City 582|itaituba,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=itaituba,br
#
#
# Finding City 583|cape town,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=cape+town,za
#
#
# Finding City 584|robertsport,lr
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=robertsport,lr
#
#
# Finding City 585|antofagasta,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=antofagasta,cl
#
#
# Finding City 586|esfarayen,ir
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=esfarayen,ir
#
#
# Finding City 587|jiaonan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=jiaonan,cn
#
#
# Finding City 588|worland,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=worland,us
#
#
# Finding City 589|dukat,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=dukat,ru
#
#
# Finding City 590|uyuni,bo
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=uyuni,bo
#
#
# Finding City 591|boa vista,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=boa+vista,br
#
#
# Finding City 592|estelle,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=estelle,us
#
#
# Finding City 593|kazachinskoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=kazachinskoye,ru
#
#
# Finding City 594|yerbogachen,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=yerbogachen,ru
#
#
# Finding City 595|talcahuano,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=talcahuano,cl
#
#
# Finding City 596|pergamino,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=pergamino,ar
#
#
# Finding City 597|sechura,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=sechura,pe
#
#
# Finding City 598|eskasem,af
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=eskasem,af
#
#
# Finding City 599|mar del plata,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=mar+del+plata,ar
#
#
# Finding City 600|okitipupa,ng
#
# https://api.openweathermap.org/data/2.5/weather?appid=7f565398c1a0ab6b2dde537d78e10dc8&units=imperial&q=okitipupa,ng

# %%
#Create Pandas DataFrame
summary = ["name", "sys.country", "dt","coord.lat", "coord.lon","main.temp_max","main.humidity","wind.speed","clouds.all"]
data = [respone(*summary) for response in weather_data]
column_names = ["City","Country","Date","Latitude", "Longitude","Temperature","Humidity","Wind speed","Cloudliness"]
weather_data = pd.DataFrame(data, columns=column_names)

weather_data.head()
# Out:
# Empty DataFrame
# Columns: [City, Country, Date, Latitude, Longitude, Temperature, Humidity, Wind speed, Cloudliness]
# Index: []
